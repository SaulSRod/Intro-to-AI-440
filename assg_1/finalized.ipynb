# %% [markdown]
# **THIS NOTEBOOK IS WHERE YOU CAN RUN THE FINALIZED CODE TO ANSWER PARTS AS NECESSARY**

# %% [markdown]
# **PART ZERO - MAZE GENERATION**
# - create_maze(seed)
#     - Function to create mazes with a specific seed to recreate randomness for debugging
#     - seed is used to implement randomness when deciding if a cell is blocked or open. seed helps for debugging
# - save_maze(maze, file_name)
#     - saves the maze generated by create_maze to the file name provided
#
#
# - maze_gen.py
#     - Code used to make the mazes. They are all visualized using ASCII
#     - Mazes generated can be found in Assg1/mazes_generated
#
# - retrieve_maze(maze_name)
#     - Retrieves any maze# generated
#     - \# is any valid maze number 1-50
#
# - find_cell(maze, symbol)
#     - Finds the specific either the start or end coordinates in the maze provided

# %%
#DO NOT RUN
"""
import maze_generation.maze_gen as mg
for i in range(1,51):
    maze = mg.create_maze(SEED=i)
    mg.save_maze(maze, f"maze{i}.txt")
"""
# Out:
# '\nimport maze_generation.maze_gen as mg\nfor i in range(1,51):\n    maze = mg.create_maze(SEED=i)\n    mg.save_maze(maze, f"maze{i}.txt")\n'

# %%
import maze_generation.maze_gen as mg
maze_name = 'maze5'
maze = mg.retrieve_maze(maze_name)

maze_start = mg.find_cell(maze, 'S')
maze_end = mg.find_cell(maze, '!')
print(f"start:{maze_start} end:{maze_end}")

# %% [markdown]
# **PART TWO - COMPARING REPEATED FORWARD A\* TIE BREAKING METHODS**
# - analysis_q2(number)
#     - Used to visually compare the # of cells expanded
#     - number used is the number of mazes that will be compared to each other -> OPTIONAL
#     - Default of all 50 mazes will be used, otherwise maze #1 up to maze #number will analyzed

# %%
import analysis.parts_analysis as anal
anal.analysis_q2(3)
# Out:
# Testing Forward A* tie breaker based on cells expanded using 3 mazes...
# Maze       | Cells expanded by largest g | Cells expanded by Smallest g | Large Time | Small Time | Status
# ----------------------------------------------------------------------------------------------------------
# maze1      | 53122.00                    | 828474.00                    | 0.2421     | 3.2539     | Start:(73, 17) | End:(11, 69) | Large G:813 | Small G:709
# maze2      | 155743.00                   | 371032.00                    | 0.6053     | 1.3708     | Start:(11, 7) | End:(63, 31) | Large G:1863 | Small G:1549
# maze3      | 652961.00                   | 1789525.00                   | 2.4728     | 6.6801     | Start:(75, 31) | End:(97, 69) | Large G:1687 | Small G:1889
# ----------------------------------------------------------------------------------------------------------
# Average    | 287275.33                   | 996343.67                    | 1.1067     | 3.7683     |
# % Improved | -0.71                       | -                            | -0.7063    | -          |

# %%
import analysis.parts_analysis as anal
anal.analysis_q3()
# Out:
# Running experiments on 50 mazes...
# Maze       | Fwd Exp    | Bwd Exp    | Fwd Time   | Bwd Time   | Status
# ---------------------------------------------------------------------------
# maze1      | 53122      | 867400     | 0.2458     | 4.2579     | DiffLen
# maze2      | 155743     | 320669     | 0.6244     | 1.3723     | DiffLen
# maze3      | 652961     | 1506987    | 2.9788     | 6.9644     | DiffLen
# maze4      | 2209490    | 2294901    | 9.0904     | 9.4878     | DiffLen
# maze5      | 181520     | 559091     | 0.7617     | 2.5797     | DiffLen
# maze6      | 381220     | 1123962    | 1.5018     | 4.6633     | DiffLen
# maze7      | 68194      | 1017615    | 0.3129     | 4.8615     | DiffLen
# maze8      | 66497      | 926974     | 0.2803     | 3.9725     | DiffLen
# maze9      | 73371      | 412381     | 0.3166     | 1.8793     | DiffLen
# maze10     | 230876     | 1276814    | 0.9357     | 5.6670     | DiffLen
# maze11     | 314968     | 1438627    | 1.2477     | 6.1646     | DiffLen
# maze12     | 4456       | 33863      | 0.0217     | 0.1598     | DiffLen
# maze13     | 374192     | 702357     | 1.4729     | 3.0972     | DiffLen
# maze14     | 254222     | 1504492    | 1.0161     | 6.5843     | DiffLen
# maze15     | 3755       | 15814      | 0.0177     | 0.0667     | DiffLen
# maze16     | 379446     | 709042     | 1.4238     | 2.8049     | DiffLen
# maze17     | 128642     | 1561325    | 0.5577     | 7.2300     | DiffLen
# maze18     | 206907     | 280230     | 0.8360     | 1.1760     | DiffLen
# maze19     | 29824      | 264559     | 0.1396     | 1.1770     | DiffLen
# maze20     | 63597      | 302922     | 0.2743     | 1.4814     | DiffLen
# maze21     | 123050     | 1317452    | 0.5413     | 6.1208     | DiffLen
# maze22     | 72281      | 356636     | 0.3003     | 1.5413     | DiffLen
# maze23     | 60233      | 388240     | 0.2702     | 1.7886     | DiffLen
# maze24     | 82287      | 442629     | 0.3372     | 2.1082     | DiffLen
# maze25     | 92662      | 294403     | 0.3763     | 1.2602     | DiffLen
# maze26     | 396775     | 2720416    | 1.5657     | 11.1610    | DiffLen
# maze27     | 5058       | 11413      | 0.0231     | 0.0485     | DiffLen
# maze28     | 14353      | 81742      | 0.0666     | 0.3581     | DiffLen
# maze29     | 8765       | 39735      | 0.0379     | 0.1606     | DiffLen
# maze30     | 51898      | 229113     | 0.2262     | 1.0423     | DiffLen
# maze31     | 21802      | 55487      | 0.0940     | 0.2379     | DiffLen
# maze32     | 78670      | 260839     | 0.3294     | 1.1562     | DiffLen
# maze33     | 22721      | 66163      | 0.0990     | 0.2786     | DiffLen
# maze34     | 75095      | 713996     | 0.3196     | 3.6353     | DiffLen
# maze35     | 94283      | 315792     | 0.4226     | 1.3711     | DiffLen
# maze36     | 118965     | 354018     | 0.4919     | 1.4959     | DiffLen
# maze37     | 85577      | 1063214    | 0.3644     | 4.8135     | DiffLen
# maze38     | 2127919    | 3808685    | 8.0604     | 15.2501    | DiffLen
# maze39     | 76584      | 981400     | 0.3472     | 4.7122     | DiffLen
# maze40     | 216829     | 1354162    | 0.9362     | 6.1471     | DiffLen
# maze41     | 88147      | 528821     | 0.3691     | 2.3655     | DiffLen
# maze42     | 694619     | 1632057    | 2.7689     | 7.4419     | DiffLen
# maze43     | 42336      | 169691     | 0.1753     | 0.7805     | DiffLen
# maze44     | 18463      | 81441      | 0.0831     | 0.3607     | DiffLen
# maze45     | 24679      | 75497      | 0.1046     | 0.3273     | DiffLen
# maze46     | 373696     | 312951     | 1.4107     | 1.3514     | DiffLen
# maze47     | 60914      | 989983     | 0.2816     | 4.7886     | DiffLen
# maze48     | 43479      | 189563     | 0.1789     | 0.8042     | DiffLen
# maze49     | 1524       | 3311       | 0.0087     | 0.0143     | DiffLen
# maze50     | 214130     | 1058216    | 0.8882     | 4.3592     | DiffLen
# ---------------------------------------------------------------------------
# Average    | 224415.9   | 740341.8   | -          | -          |

# %% [markdown]
# **PART FIVE - COMPARING REPEATED FORWARD A\* AND ADAPTIVE A\***
# - analysis_q5(number)
#     - Used to visually compare the # of cells expanded, as well as runtime for each method used
#     - number used is the number of mazes that will be compared to each other -> OPTIONAL
#     - Default of all 50 mazes will be used, otherwise maze #1 up to maze #number will analyzed
#     - Both Forward A* and Adaptive A* prioritize largest g values found

# %%
import analysis.parts_analysis as anal
anal.analysis_q5(3)
# Out:
# Testing Forward A* and Adaptive A* on cells expanded using 3 mazes...
# Maze       | Cells expanded Forward A*   | Cells expanded by Adaptive A* | Forward Time | Adaptive Time | Status
# ----------------------------------------------------------------------------------------------------------------
# maze1      | 53122                       | 39508                         | 0.2475       | 0.2063        | Start:(73, 17) | End:(11, 69) | Path Fwd:813 | Path Adp:793
# maze2      | 155743                      | 55415                         | 0.6098       | 0.2650        | Start:(11, 7) | End:(63, 31) | Path Fwd:1863 | Path Adp:1353
# maze3      | 652961                      | 257880                        | 2.4663       | 1.3178        | Start:(75, 31) | End:(97, 69) | Path Fwd:1687 | Path Adp:1791
# ----------------------------------------------------------------------------------------------------------------
# Average    | 287275.3333                 | 117601.0000                   | 1.1079       | 0.5964        |
# % Improved | -                           | -0.4617                       | -            | -0.4617       |
