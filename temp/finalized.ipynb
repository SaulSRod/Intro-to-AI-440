# %% [markdown]
# **THIS NOTEBOOK IS WHERE YOU CAN RUN THE FINALIZED CODE TO ANSWER PARTS AS NECESSARY**

# %% [markdown]
# **PART ZERO - MAZE GENERATION**
# - create_maze(seed)
#     - Function to create mazes with a specific seed to recreate randomness for debugging
#     - seed is used to implement randomness when deciding if a cell is blocked or open. seed helps for debugging
# - save_maze(maze, file_name)
#     - saves the maze generated by create_maze to the file name provided
#
#
# - maze_gen.py
#     - Code used to make the mazes. They are all visualized using ASCII
#     - Mazes generated can be found in Assg1/mazes_generated
#
# - retrieve_maze(maze_name)
#     - Retrieves any maze# generated
#     - \# is any valid maze number 1-50
#
# - find_cell(maze, symbol)
#     - Finds the specific either the start or end coordinates in the maze provided

# %%
#DO NOT RUN
"""
import maze_generation.maze_gen as mg
for i in range(1,51):
    maze = mg.create_maze(SEED=i)
    mg.save_maze(maze, f"maze{i}.txt")
"""
# Out:
# '\nimport maze_generation.maze_gen as mg\nfor i in range(1,51):\n    maze = mg.create_maze(SEED=i)\n    mg.save_maze(maze, f"maze{i}.txt")\n'

# %%
import maze_generation.maze_gen as mg
maze_name = 'maze5'
maze = mg.retrieve_maze(maze_name)

maze_start = mg.find_cell(maze, 'S')
maze_end = mg.find_cell(maze, '!')
print(f"start:{maze_start} end:{maze_end}")

# %% [markdown]
# **PART TWO - COMPARING REPEATED FORWARD A\* TIE BREAKING METHODS**
# - analysis_q2(number)
#     - Used to visually compare the # of cells expanded
#     - number used is the number of mazes that will be compared to each other -> OPTIONAL
#     - Default of all 50 mazes will be used, otherwise maze #1 up to maze #number will analyzed

# %%
import analysis.parts_analysis as anal
anal.analysis_q2()
# Out:
# Testing Forward A* tie breaker based on cells expanded using 50 mazes...
# Maze       | Cells expanded by largest g | Cells expanded by Smallest g | Large Time | Small Time | Path Len
# ----------------------------------------------------------------------------------------------------------
# maze1      | 53122.00                    | 828474.00                    | 0.2006     | 2.6306     | Large G:813 | Small G:709
# maze2      | 155743.00                   | 371032.00                    | 0.5135     | 1.1823     | Large G:1863 | Small G:1549
# maze3      | 652961.00                   | 1789525.00                   | 2.0629     | 6.4037     | Large G:1687 | Small G:1889
# maze4      | 2209490.00                  | 2056537.00                   | 8.0600     | 6.4511     | Large G:2915 | Small G:2437
# maze5      | 181520.00                   | 846140.00                    | 0.6451     | 2.7435     | Large G:1211 | Small G:1117
# ...

# %%
import analysis.parts_analysis as anal
anal.analysis_q3()
# Out:
# Running Forward vs Backward Repeated A* experiments on 50 mazes...
# Maze       | Fwd Exp    | Bwd Exp    | Fwd Time   | Bwd Time   | Status
# ---------------------------------------------------------------------------
# maze1      | 53122      | 867400     | 0.1928     | 3.5413     | DiffLen
# maze2      | 155743     | 320669     | 0.4982     | 1.1100     | DiffLen
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import analysis.parts_analysis as anal
# ----> 2 anal.analysis_q3()
#
# File c:\Users\Saul\Desktop\Intro to AI 440\assg_1\analysis\parts_analysis.py:167, in analysis_q3(num_mazes)
#     165 # Run Repeated Backward A*
#     166 t0 = time.time()
# --> 167 bwd_path, bwd_exp = search.repeated_backward_a_star(start, goal, maze_list, -1)
#     168 t1 = time.time()
#     169 bwd_time = t1 - t0
#
# ...

# %% [markdown]
# **PART FIVE - COMPARING REPEATED FORWARD A\* AND ADAPTIVE A\***
# - analysis_q5(number)
#     - Used to visually compare the # of cells expanded, as well as runtime for each method used
#     - number used is the number of mazes that will be compared to each other -> OPTIONAL
#     - Default of all 50 mazes will be used, otherwise maze #1 up to maze #number will analyzed
#     - Both Forward A* and Adaptive A* prioritize largest g values found

# %%
import analysis.parts_analysis as anal
anal.analysis_q5()
# Out:
# Testing Forward A* and Adaptive A* on cells expanded using 50 mazes...
# Maze       | Cells expanded Forward A*   | Cells expanded by Adaptive A* | Forward Time | Adaptive Time | Status
# ----------------------------------------------------------------------------------------------------------------
# maze1      | 53122                       | 39508                         | 0.1911       | 0.1645        | Len Fwd:813 | Len Adp:793
# maze2      | 155743                      | 55415                         | 0.4892       | 0.2157        | Len Fwd:1863 | Len Adp:1353
# maze3      | 652961                      | 257880                        | 1.9474       | 1.0707        | Len Fwd:1687 | Len Adp:1791
# maze4      | 2209490                     | 323462                        | 7.9022       | 1.1598        | Len Fwd:2915 | Len Adp:2995
# maze5      | 181520                      | 97142                         | 0.6037       | 0.3684        | Len Fwd:1211 | Len Adp:1607
# ...

# %%
import analysis.parts_analysis as anal
anal.analysis_q2_fig9()
# Out:
# Testing Forward A* tie breaker based on cells expanded using Figure 9 maze...
# Maze       | Cells expanded by largest g | Cells expanded by Smallest g | Large Time | Small Time | Path Len
# ----------------------------------------------------------------------------------------------------------
# test_maze_fig9 | 8.00                        | 24.00                        | 0.0002     | 0.0001     | OK
# ----------------------------------------------------------------------------------------------------------
# Average    | 8.00                        | 24.00                        | 0.0002     | 0.0001     |
# % Improved | -0.67                       | -                            | 0.1581     | -          |
